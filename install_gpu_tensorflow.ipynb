# %% [markdown]
# # Configurando GPU RTX A2000 com tensorflow no Windows 11
#
# Criado por: Nielsen C. Damasceno Dantas
#
#
# Data de criacao: 28/06/2024
#
# ______
#
# Requeriments:
# - tensorflow-gpu==2.10.0
# - pandas
# - gensim==3.8.3
# - scikit-learn
# - seaborn
# - matplotlib
# - Python 3.8.19

# %% [markdown]
# ## Faça o download do CUDA toolkit 11.6 para Windows 11
# https://developer.nvidia.com/cuda-11-6-0-download-archive?target_os=Windows&target_arch=x86_64

# %% [markdown]
# ## Faça o Download cuDNN v8.6.0
# https://developer.nvidia.com/rdp/cudnn-archive

# %% [markdown]
# ## Siga os passos conforme esse tutorial aqui para configuração do Path
# https://medium.com/analytics-vidhya/using-tensorflow-on-windows-10-with-nvidia-rtx-3000-series-gpus-637ab2a4b163

# %% [markdown]
# ## Instale a lib zlibdll
# Download and extract the zlib package from http://www.winimage.com/zLibDll/zlib123dllx64.zip for 64 bit windows then copy the zlibdll file into cudnn/bin

# %%
import tensorflow as tf

with tf.compat.v1.Session() as sess:
  a = tf.constant(3.0)  
  b = tf.constant(4.0)
  c = a+b
  print(sess.run(c))
# Out:
# 7.0

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras import datasets, layers, models
# import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# %%
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

# %%
model.compile(optimizer='Adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True))

# %%
history = model.fit(train_images, train_labels, batch_size=255, epochs=100)
# Out:
# Epoch 1/100
# 197/197 [==============================] - 2s 6ms/step - loss: 1.8165
# Epoch 2/100
# 197/197 [==============================] - 1s 5ms/step - loss: 1.4771
# Epoch 3/100
# 197/197 [==============================] - 1s 5ms/step - loss: 1.3312
# Epoch 4/100
# 197/197 [==============================] - 1s 5ms/step - loss: 1.2388
# Epoch 5/100
# 197/197 [==============================] - 1s 5ms/step - loss: 1.1789
# Epoch 6/100
# 197/197 [==============================] - 1s 5ms/step - loss: 1.1245
# Epoch 7/100
# 197/197 [==============================] - 1s 5ms/step - loss: 1.0944
# Epoch 8/100
# 197/197 [==============================] - 1s 5ms/step - loss: 1.0652
# Epoch 9/100
# 197/197 [==============================] - 1s 5ms/step - loss: 1.0353
# Epoch 10/100
# 197/197 [==============================] - 1s 5ms/step - loss: 1.0037
# Epoch 11/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.9868
# Epoch 12/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.9575
# Epoch 13/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.9403
# Epoch 14/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.9311
# Epoch 15/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.9049
# Epoch 16/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.8921
# Epoch 17/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.8722
# Epoch 18/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.8574
# Epoch 19/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.8444
# Epoch 20/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.8242
# Epoch 21/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.8166
# Epoch 22/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.8081
# Epoch 23/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7859
# Epoch 24/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7732
# Epoch 25/100
# 197/197 [==============================] - 1s 4ms/step - loss: 0.7641
# Epoch 26/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7483
# Epoch 27/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7457
# Epoch 28/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7331
# Epoch 29/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7249
# Epoch 30/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7097
# Epoch 31/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.7016
# Epoch 32/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6999
# Epoch 33/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6784
# Epoch 34/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6740
# Epoch 35/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6634
# Epoch 36/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6524
# Epoch 37/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6445
# Epoch 38/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6330
# Epoch 39/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6221
# Epoch 40/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6186
# Epoch 41/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.6080
# Epoch 42/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5970
# Epoch 43/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5866
# Epoch 44/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5824
# Epoch 45/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5755
# Epoch 46/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5680
# Epoch 47/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5532
# Epoch 48/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5476
# Epoch 49/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5439
# Epoch 50/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5336
# Epoch 51/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5303
# Epoch 52/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5201
# Epoch 53/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5104
# Epoch 54/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.5005
# Epoch 55/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4957
# Epoch 56/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4871
# Epoch 57/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4939
# Epoch 58/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4710
# Epoch 59/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4727
# Epoch 60/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4623
# Epoch 61/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4513
# Epoch 62/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4537
# Epoch 63/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4402
# Epoch 64/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4343
# Epoch 65/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4339
# Epoch 66/100
# 197/197 [==============================] - 1s 4ms/step - loss: 0.4184
# Epoch 67/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4167
# Epoch 68/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4118
# Epoch 69/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.4011
# Epoch 70/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.3961
# Epoch 71/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.3926
# Epoch 72/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.3875
# Epoch 73/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.3744
# Epoch 74/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.3742
# Epoch 75/100
# 197/197 [==============================] - 1s 5ms/step - loss: 0.3665
# Epoch 76/100
#  23/197 [==>...........................] - ETA: 0s - loss: 0.3611

# %% [markdown]
# ![image.png](attachment:image.png)
